# %% [markdown]
# # XGBoost–CNN Hybrid Model for Wind Speed Forecasting
# ## Multivariate Standalone Optimal Model with Residual Correction
# ### Sections: Original Model | Grid Search | Randomized Search | Optuna
#
# **Methodology Overview:**
# 1. An XGBoost primary model (pre-tuned via Optuna) generates wind-speed forecasts.
# 2. The residuals from XGBoost are modelled by a 1-D CNN residual-correction network.
# 3. The hybrid forecast is: **Ŷ_hybrid = Ŷ_XGB + Ŷ_CNN_residual**
# 4. All hyperparameter searches use only the first 80% of data (training set) with
#    `TimeSeriesSplit` cross-validation — the held-out last 20% is never seen during tuning.

# %% [markdown]
# ## 1. Installing Required Packages

# %%
# !pip install -U scikit-learn scikeras

# !pip install scikeras

import sklearn
import scikeras

print("scikit-learn version:", sklearn.__version__)
print("scikeras version:", scikeras.__version__)
#scikit-learn >= 1.2.0
#scikeras >= 0.10.0
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.13.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (26.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.13.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.9.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (26.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.3)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# scikit-learn version: 1.9.0
# scikeras version: 0.13.0

# %%
# INSTALLING REQUIRED PACKAGES
# !pip install statsmodels optuna tabulate xgboost scikeras --quiet

# %% [markdown]
# ## 2. Imports & Global Settings

# %%
# Standard libraries
import sys
import os
import warnings
import random
warnings.filterwarnings("ignore")

# Data manipulation
import numpy as np   # Numerical operations
import pandas as pd  # Data manipulation and analysis

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Preprocessing & model selection
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (TimeSeriesSplit, GridSearchCV,
                                     RandomizedSearchCV)
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score)
from scipy.stats import randint, uniform

# XGBoost
import xgboost as xgb

# TensorFlow / Keras (CNN)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# SciKeras wrapper (scikit-learn API for Keras)
from scikeras.wrappers import KerasRegressor

# Optuna (Bayesian hyperparameter optimisation)
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)  # suppress verbose trial logs

# ── Global random seed (set once; reused throughout) ──────────────────────────
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print(f"Global random seed set to {RANDOM_SEED}")
# Out:
# Global random seed set to 42

# %% [markdown]
# ## 3. Loading the Dataset

# %%
# =============================================================================
# LOADING THE DATASET
# Dataset sources:
#   https://drive.google.com/file/d/1Z_KsoIumw-fvivVombIoWuRo0LOe2nCb/view?usp=sharing
#   https://drive.google.com/file/d/1aD1PXfwEEZ_F2lQgxuPfj-TVbxQ6NajK/view?usp=sharing
# =============================================================================

file_id      = "1c5KmcFD1TOsqASqzy0KiYo-7IzgBFuhk"   # Variable Set 2 dataset
download_url = f"https://drive.google.com/uc?id={file_id}"

df = pd.read_csv(download_url)

# Create a proper datetime index from year / month / day columns
df['Date'] = pd.to_datetime({
    'year':  df['YEAR'],
    'month': df['MO'],
    'day':   df['DY']
})
df = df.set_index('Date')

# Drop the raw date columns (now encoded in the index)
df = df.drop(columns=["YEAR", "MO", "DY"])

print("Dataset loaded successfully.")
print(f"Shape: {df.shape}")
print("\nFirst 5 rows:")
display(df.head())
print("\nColumns:", df.columns.tolist())
# Out:
# Dataset loaded successfully.
# Shape: (4015, 14)
#
# First 5 rows:
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin  SURF_PRESSURE_DIFF  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939                0.03
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199               -0.03
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526               -0.15
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200               -0.03
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125               -0.01
#
#             AVG_TEMP    WD_cos  RH_lag1  MONOSOON_SEASON_Southwest_Monsoon  \
# Date
# 2013-01-03      26.4  0.898028    86.19                                  0
# 2013-01-04      25.1  0.905569    86.26                                  0
# 2013-01-05      26.9  0.826098    86.31                                  0
# 2013-01-06      27.3  0.887815    86.88                                  0
# 2013-01-07      25.9  0.929776    88.09                                  0
#
#             MAX_TEMP  SL_PRESSURE_lag1  CLOUD_COVER  WS10M
# Date
# 2013-01-03     28.38            1010.4          8.0   4.75
# 2013-01-04     27.58            1011.0          8.0   5.74
# 2013-01-05     26.16            1010.1          8.0   5.79
# 2013-01-06     27.75            1007.5          7.0   4.52
# 2013-01-07     26.70            1008.2          8.0   4.66
# Columns: ['WS10M_lag1', 'RH', 'MIN_TEMP', 'PREC', 'WD_sin', 'SURF_PRESSURE_DIFF', 'AVG_TEMP', 'WD_cos', 'RH_lag1', 'MONOSOON_SEASON_Southwest_Monsoon', 'MAX_TEMP', 'SL_PRESSURE_lag1', 'CLOUD_COVER', 'WS10M']

# %% [markdown]
# ## 4. Primary Train–Test Split (80 / 20, Time-Based)

# %%
# =============================================================================
# Train-test split — first 80% for training, last 20% for testing.
# Temporal ordering is strictly preserved; no shuffling is applied.
# =============================================================================

X = df.drop(columns=['WS10M'])  # Feature matrix
y = df['WS10M']                 # Target: wind speed (m/s)

split_index = int(len(X) * 0.8)  # 80% training, 20% testing

X_train = X.iloc[:split_index]
y_train = y.iloc[:split_index]
X_test  = X.iloc[split_index:]
y_test  = y.iloc[split_index:]

print(f"Total samples : {len(X)}")
print(f"Training set  : {X_train.shape}  (first {split_index} samples)")
print(f"Test set      : {X_test.shape}  (last {len(X) - split_index} samples)")
print(f"\nTrain period: {X_train.index[0].date()}  →  {X_train.index[-1].date()}")
print(f"Test period : {X_test.index[0].date()}  →  {X_test.index[-1].date()}")
# Out:
# Total samples : 4015
# Training set  : (3212, 13)  (first 3212 samples)
# Test set      : (803, 13)  (last 803 samples)
#
# Train period: 2013-01-03  →  2021-10-19
# Test period : 2021-10-20  →  2023-12-31

# %% [markdown]
# ## 5. Shared Helper Functions

# %%
# =============================================================================
# Helper functions used by all model sections below.
# Defined once here to avoid repetition across sections.
# =============================================================================

def evaluate(y_true, y_pred, label=""):
    """Print and return evaluation metrics for the residual correction model."""
    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2   = r2_score(y_true, y_pred)
    print(f"{label} MSE:  {mse:.4f}")
    print(f"{label} RMSE: {rmse:.4f}")
    print(f"{label} MAE:  {mae:.4f}")
    print(f"{label} MAPE: {mape:.2f}%")
    print(f"{label} R²:   {r2:.4f}")
    return mse, rmse, mae, mape, r2


def evaluate_performance(y_true, y_pred, set_name="Dataset"):
    """Evaluate and return metrics as a dictionary for the hybrid model."""
    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2   = r2_score(y_true, y_pred)
    print(f"\n--- {set_name} Metrics ---")
    print(f"RMSE: {rmse:.4f}")
    print(f"MSE:  {mse:.4f}")
    print(f"MAE:  {mae:.4f}")
    print(f"MAPE: {mape:.4f}%")
    print(f"R²:   {r2:.4f}")
    return {'RMSE': rmse, 'MSE': mse, 'MAE': mae, 'MAPE': mape, 'R²': r2}

# %% [markdown]
# ## 6. XGBoost Primary Model (Optuna-Optimised Parameters)
#
# The XGBoost model was previously optimised with Optuna and achieved the
# following standalone wind-speed forecasting performance:
#
# | Method | Train MSE | Test MSE | Train MAE | Test MAE | Train RMSE | Test RMSE | Train MAPE (%) | Test MAPE (%) | Train R² | Test R² |
# |--------|-----------|----------|-----------|----------|------------|-----------|----------------|---------------|----------|---------|
# | Optuna | 0.211530  | 0.527328 | 0.360631  | 0.551346 | 0.459923   | 0.726173  | 9.983644       | 14.987060     | 0.916036 | 0.781323|

# %%
# =============================================================================
# XGBoost Primary Model
# Best parameters sourced from prior Optuna optimisation run.
# The model is fitted on X_train only; predictions over the full dataset are
# stored so residuals can be computed for the CNN correction layer.
# =============================================================================

# Best Parameters: {'n_estimators': 300, 'max_depth': 6,
#   'learning_rate': 0.02017215364230889, 'min_child_weight': 5,
#   'gamma': 0.019237778052053844, 'subsample': 0.618408743715084}
Best_Parameters = {
    'n_estimators':     300,
    'max_depth':        6,
    'learning_rate':    0.02017215364230889,
    'gamma':            0.019237778052053844,
    'subsample':        0.618408743715084,
    'min_child_weight': 5
}

# Initialise XGBRegressor with optimal parameters
best_xgb = xgb.XGBRegressor(**Best_Parameters, random_state=RANDOM_SEED)

# Fit on training data only (test set remains unseen until evaluation)
best_xgb.fit(X_train, y_train)
print(f"XGBoost fitted. Parameters: {Best_Parameters}")

# ── Train / Test predictions ──────────────────────────────────────────────────
y_train_pred_xgb = best_xgb.predict(X_train)
y_test_pred_xgb  = best_xgb.predict(X_test)

# ── Evaluation metrics ────────────────────────────────────────────────────────
xgb_train_mse  = mean_squared_error(y_train, y_train_pred_xgb)
xgb_test_mse   = mean_squared_error(y_test,  y_test_pred_xgb)
xgb_train_mae  = mean_absolute_error(y_train, y_train_pred_xgb)
xgb_test_mae   = mean_absolute_error(y_test,  y_test_pred_xgb)
xgb_train_rmse = np.sqrt(xgb_train_mse)
xgb_test_rmse  = np.sqrt(xgb_test_mse)
xgb_train_mape = np.mean(np.abs((y_train - y_train_pred_xgb) / y_train)) * 100
xgb_test_mape  = np.mean(np.abs((y_test  - y_test_pred_xgb)  / y_test))  * 100
xgb_train_r2   = r2_score(y_train, y_train_pred_xgb)
xgb_test_r2    = r2_score(y_test,  y_test_pred_xgb)

print(f"\nTrain MSE:  {xgb_train_mse:.4f}  | Test MSE:  {xgb_test_mse:.4f}")
print(f"Train MAE:  {xgb_train_mae:.4f}  | Test MAE:  {xgb_test_mae:.4f}")
print(f"Train RMSE: {xgb_train_rmse:.4f} | Test RMSE: {xgb_test_rmse:.4f}")
print(f"Train MAPE: {xgb_train_mape:.4f}%| Test MAPE: {xgb_test_mape:.4f}%")
print(f"Train R²:   {xgb_train_r2:.4f}  | Test R²:   {xgb_test_r2:.4f}")

# ── Summary table (Plotly) ────────────────────────────────────────────────────
summary_df = pd.DataFrame({
    'Parameter/Metric': list(Best_Parameters.keys()) +
                        ['Train MSE', 'Test MSE', 'Train MAE', 'Test MAE',
                         'Train RMSE', 'Test RMSE', 'Train MAPE (%)',
                         'Test MAPE (%)', 'Train R²', 'Test R²'],
    'Value': list(Best_Parameters.values()) +
             [xgb_train_mse, xgb_test_mse, xgb_train_mae, xgb_test_mae,
              xgb_train_rmse, xgb_test_rmse, xgb_train_mape, xgb_test_mape,
              xgb_train_r2, xgb_test_r2]
})
summary_df['Value'] = summary_df['Value'].apply(lambda x: f"{x:.6f}")

fig_table = go.Figure(go.Table(
    header=dict(
        values=['<b>Parameter / Metric</b>', '<b>Value</b>'],
        fill_color='steelblue',
        font=dict(color='white', size=13),
        align='left'
    ),
    cells=dict(
        values=[summary_df['Parameter/Metric'], summary_df['Value']],
        fill_color=[['lightcyan' if i % 2 == 0 else 'white'
                     for i in range(len(summary_df))]],
        align='left'
    )
))
fig_table.update_layout(
    title="XGBoost Optimal Parameters & Model Performance Metrics",
    template="plotly_white", height=600
)
fig_table.show()
# Out:
# XGBoost fitted. Parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.02017215364230889, 'gamma': 0.019237778052053844, 'subsample': 0.618408743715084, 'min_child_weight': 5}
#
# Train MSE:  0.2103  | Test MSE:  0.5259
# Train MAE:  0.3590  | Test MAE:  0.5495
# Train RMSE: 0.4586 | Test RMSE: 0.7252
# Train MAPE: 9.9187%| Test MAPE: 14.9222%
# Train R²:   0.9165  | Test R²:   0.7819
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3710325e-4b39-4f44-be3d-698367299e2e" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3710325e-4b39-4f44-be3d-698367299e2e")) {                    Plotly.newPlot(                        "3710325e-4b39-4f44-be3d-698367299e2e",                        [{"cells":{"align":"left","fill":{"color":[["lightcyan","white","lightcyan","white","lightcyan","white","lightcyan","white","lightcyan","white","lightcyan","white","lightcyan","white","lightcyan","white"]]},"values":[["n_estimators","max_depth","learning_rate","gamma","subsample","min_child_weight","Train MSE","Test MSE","Train MAE","Test MAE","Train RMSE","Test RMSE","Train MAPE (%)","Test MAPE (%)","Train R²","Test R²"],["300.000000","6.000000","0.020172","0.019238","0.618409","5.000000","0.210277","0.525893","0.358982","0.549507","0.458559","0.725185","9.918672","14.922161","0.916534","0.781918"]]},"header":{"align":"left","fill":{"color":"steelblue"},"font":{"color":"white","size":13},"values":["\u003cb\u003eParameter \u002f Metric\u003c\u002fb\u003e","\u003cb\u003eValue\u003c\u002fb\u003e"]},"type":"table"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777 ...

# %% [markdown]
# ## 7. Out-of-Fold XGBoost Residuals (Training Set)
#
# The residual-correction CNN must learn to predict the errors XGBoost makes on
# **unseen** data, because that is the only situation it will ever face in
# deployment (XGBoost forecasts, then CNN corrects). Predicting on the same
# rows XGBoost was fitted on gives residuals that are systematically smaller
# and differently shaped than genuine out-of-sample errors, since a boosted-
# tree ensemble can partially fit noise in rows it has already seen. Training
# the CNN on those artificially small, in-sample residuals teaches it the
# wrong correction pattern, and is a likely explanation for the small hybrid-
# model gains observed previously.
#
# The fix below generates **out-of-fold (OOF)** residuals for the training set
# using the same `TimeSeriesSplit` scheme already used elsewhere in this
# notebook for CNN cross-validation. For every fold, a fresh XGBoost model is
# fit only on data strictly before the fold and used to predict only that
# fold -- so every training-set residual fed to the CNN is, from that fold
# model's perspective, a genuine out-of-sample residual. The test set is
# untouched here; it was always out-of-sample because `best_xgb` never saw it
# during fitting.

# %%
# =============================================================================
# OUT-OF-FOLD (OOF) XGBOOST RESIDUALS ON THE TRAINING SET
# -----------------------------------------------------------------------------
# WHAT THIS CELL DOES
#   For each TimeSeriesSplit fold, we fit a FRESH XGBoost model (same tuned
#   hyperparameters as `best_xgb`) using only the rows strictly before the
#   fold's validation window, then predict on that validation window only.
#   Every prediction produced this way is out-of-sample with respect to the
#   model that produced it -- exactly like the situation at deployment time.
#
# WHY NOT JUST REUSE `best_xgb` (the model fit on the whole training set)?
#   `best_xgb` has already seen every training row during fitting, so its
#   predictions on those same rows are in-sample and would recreate the
#   original leakage problem. OOF cross-validation is the standard way to
#   obtain leakage-free "training set" predictions from a model that must
#   also be fit on the full training set for later deployment.
#
# THE UNAVOIDABLE GAP
#   TimeSeriesSplit needs an initial block of data to train the very first
#   fold, so the earliest rows of the training set (before the first fold's
#   validation window begins) never appear in any validation fold and cannot
#   get a leakage-free OOF prediction. We leave these as NaN here and drop
#   them explicitly later -- filling them with an in-sample prediction would
#   silently reintroduce the leakage this cell exists to remove.
# =============================================================================

N_SPLITS_OOF = 5  # same fold count used later for CNN cross-validation
tscv_oof = TimeSeriesSplit(n_splits=N_SPLITS_OOF)

# Pre-allocate with NaN -- rows never selected as a validation fold (the
# initial training block) keep their NaN and are dropped further down.
oof_pred_train = np.full(shape=len(X_train), fill_value=np.nan)

print(f"Generating out-of-fold XGBoost predictions "
      f"({N_SPLITS_OOF}-fold TimeSeriesSplit) on {len(X_train)} training rows...\n")

for fold_i, (fold_train_idx, fold_val_idx) in enumerate(tscv_oof.split(X_train), start=1):
    # Fit a FRESH XGBoost (same tuned hyperparameters as best_xgb) using only
    # data strictly earlier than this fold's validation window.
    fold_model = xgb.XGBRegressor(**Best_Parameters, random_state=RANDOM_SEED)
    fold_model.fit(X_train.iloc[fold_train_idx], y_train.iloc[fold_train_idx])

    # Predict ONLY on the held-out fold -- genuinely out-of-sample for this model
    fold_val_pred = fold_model.predict(X_train.iloc[fold_val_idx])
    oof_pred_train[fold_val_idx] = fold_val_pred

    print(f"  Fold {fold_i}: fit on {len(fold_train_idx):>5} earlier rows -> "
          f"predicted {len(fold_val_idx):>5} held-out rows "
          f"(val idx {fold_val_idx[0]}:{fold_val_idx[-1]})")

n_missing = int(np.isnan(oof_pred_train).sum())
print(f"\nTraining rows with NO OOF prediction (initial block, dropped later): {n_missing}")
print(f"Training rows with a valid OOF prediction: {len(X_train) - n_missing} / {len(X_train)}")

# Out-of-fold residual = actual - OOF prediction (NaN where no OOF prediction exists)
oof_residual_train = y_train.values - oof_pred_train
# Out:
# Generating out-of-fold XGBoost predictions (5-fold TimeSeriesSplit) on 3212 training rows...
#
#   Fold 1: fit on   537 earlier rows -> predicted   535 held-out rows (val idx 537:1071)
#   Fold 2: fit on  1072 earlier rows -> predicted   535 held-out rows (val idx 1072:1606)
#   Fold 3: fit on  1607 earlier rows -> predicted   535 held-out rows (val idx 1607:2141)
#   Fold 4: fit on  2142 earlier rows -> predicted   535 held-out rows (val idx 2142:2676)
#   Fold 5: fit on  2677 earlier rows -> predicted   535 held-out rows (val idx 2677:3211)
#
# Training rows with NO OOF prediction (initial block, dropped later): 537
# Training rows with a valid OOF prediction: 2675 / 3212

# %% [markdown]
# ## 8. Combining OOF (Train) and Out-of-Sample (Test) Residuals

# %%
# =============================================================================
# COMBINE OOF (TRAIN) + OUT-OF-SAMPLE (TEST) PREDICTIONS INTO ONE RESIDUAL SERIES
# -----------------------------------------------------------------------------
#   Train rows : the out-of-fold predictions computed in the cell above
#                (oof_pred_train). Each one is out-of-sample with respect to
#                the fold model that produced it.
#   Test rows  : predictions from `best_xgb`, the single model fit on the
#                FULL training set (already computed above as
#                y_test_pred_xgb). These were always genuinely out-of-sample
#                with respect to best_xgb, so nothing changes here.
#
# The resulting 'Residual' column is out-of-sample everywhere -- this is the
# target the CNN residual-correction model is actually trained and
# evaluated against, instead of the old in-sample train residuals.
# =============================================================================

# Predictions used downstream: OOF for train rows, out-of-sample for test rows
y_pred_full_xgb = np.concatenate([oof_pred_train, y_test_pred_xgb])

df['Pred_XGB_Optuna'] = y_pred_full_xgb
df['Residual']        = df['WS10M'] - df['Pred_XGB_Optuna']

# Kept ONLY for comparison/diagnostics -- this is the old in-sample prediction
# from the model fit on the full training set. It is NOT used to train the
# CNN; it lets the size of the leakage gap be inspected directly, e.g. by
# comparing 'Residual' against WS10M - Pred_XGB_Optuna_insample.
df['Pred_XGB_Optuna_insample'] = best_xgb.predict(X)

print("Predictions and OOF (train) / out-of-sample (test) residuals added to dataframe.")
print(f"NaN residuals (initial training block with no OOF fold coverage): "
      f"{int(df['Residual'].isna().sum())}")
print(df[['WS10M', 'Pred_XGB_Optuna', 'Residual']].head(10))
print(f"\nDataframe shape: {df.shape}")

# Backup the enriched dataframe -- this is the master reference for all hybrid models
df_backup = df.copy()

# -- Visualise actual vs predicted + residuals -------------------------------
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Actual vs Predicted Wind Speed (OOF train / out-of-sample test)",
                     "Residuals (OOF train / out-of-sample test)"),
    shared_xaxes=True,
    vertical_spacing=0.12
)
fig.add_trace(go.Scatter(
    x=df.index, y=df['WS10M'],
    mode='lines', name='Actual WS10M',
    line=dict(color='steelblue', width=1.5)
), row=1, col=1)
fig.add_trace(go.Scatter(
    x=df.index, y=df['Pred_XGB_Optuna'],
    mode='lines', name='Predicted (OOF train / out-of-sample test)',
    line=dict(color='orange', width=1.5, dash='dot')
), row=1, col=1)
fig.add_trace(go.Scatter(
    x=df.index, y=df['Residual'],
    mode='lines', name='Residual',
    line=dict(color='crimson', width=1)
), row=2, col=1)
fig.add_hline(y=0, line_dash="dash", line_color="black", row=2, col=1)

fig.update_layout(
    height=700, template="plotly_white",
    title="XGBoost -- OOF (train) / Out-of-Sample (test) Predictions & Residuals",
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
)
fig.update_yaxes(title_text="Wind Speed (m/s)", row=1, col=1)
fig.update_yaxes(title_text="Residual",         row=2, col=1)
fig.update_xaxes(title_text="Date",             row=2, col=1)
fig.show()

# Save XGBoost predictions to CSV
df.to_csv('XGB_Primary_Model_Prediction.csv', index=True)
print("\nSaved to 'XGB_Primary_Model_Prediction.csv'")
# Out:
# Predictions and OOF (train) / out-of-sample (test) residuals added to dataframe.
# NaN residuals (initial training block with no OOF fold coverage): 537
#             WS10M  Pred_XGB_Optuna  Residual
# Date
# 2013-01-03   4.75              NaN       NaN
# 2013-01-04   5.74              NaN       NaN
# 2013-01-05   5.79              NaN       NaN
# 2013-01-06   4.52              NaN       NaN
# 2013-01-07   4.66              NaN       NaN
# 2013-01-08   3.61              NaN       NaN
# 2013-01-09   4.19              NaN       NaN
# 2013-01-10   5.41              NaN       NaN
# 2013-01-11   5.95              NaN       NaN
# 2013-01-12   5.80              NaN       NaN
#
# Dataframe shape: (4015, 17)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7fea4b67-ddef-49fc-b56a-dd258a0621cd" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fea4b67-ddef-49fc-b56a-dd258a0621cd")) {                    Plotly.newPlot(                        "7fea4b67-ddef-49fc-b56a-dd258a0621cd",                        [{"line":{"color":"steelblue","width":1.5},"mode":"lines","name":"Actual WS10M","x":["2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00","2013-06-03T00:00:00","2013-06 ...
# Saved to 'XGB_Primary_Model_Prediction.csv'

# %% [markdown]
# ## 9. Residual Autocorrelation (ACF) Diagnostics
#
# The CNN residual-correction model receives the same exogenous features
# XGBoost already used, so there is little genuinely new information left for
# it to exploit there. One place a secondary model *can* find real signal is
# in the residual series itself: if today's XGBoost error is correlated with
# yesterday's (or the day before's), that is a pattern the exogenous features
# alone cannot capture, but a lagged-residual feature can.
#
# The plots and tests below use only the out-of-fold (train) / out-of-sample
# (test) `'Residual'` column already computed in Section 8 -- never the old
# in-sample residuals -- so this diagnostic can't reintroduce the leakage the
# rest of this notebook was fixed to remove.

# %%
# =============================================================================
# RESIDUAL AUTOCORRELATION (ACF / PACF) DIAGNOSTICS
# -----------------------------------------------------------------------------
# WHAT THIS CELL DOES
#   Plots the autocorrelation (ACF) and partial autocorrelation (PACF) of the
#   OOF-train / OOS-test residual series, then flags which lags are
#   statistically significant using the standard large-sample white-noise
#   bound |ACF(k)| > 1.96/sqrt(N), and cross-checks with a Ljung-Box test.
#
# HOW TO READ IT
#   - ACF: correlation between the residual at time t and at time t-k.
#   - PACF: same, but with the effect of the intermediate lags removed --
#     useful for deciding how many lag features are actually independently
#     informative (e.g. if only lag 1 is significant in the PACF, adding a
#     lag-2 feature likely won't help beyond what lag-1 already captures).
#   - Shaded bands in the plots are the approximate 95% confidence interval
#     under the null hypothesis of no autocorrelation.
# =============================================================================

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf as acf_fn
from statsmodels.stats.diagnostic import acorr_ljungbox

# Use only rows with a valid (non-NaN) residual -- excludes Fold 1's
# OOF-uncovered training block (see Section 7).
residual_series = df['Residual'].dropna()
N = len(residual_series)

fig, axes = plt.subplots(1, 2, figsize=(14, 4))
plot_acf(residual_series, lags=20, ax=axes[0], alpha=0.05)
axes[0].set_title("ACF of XGBoost Residuals (OOF train + OOS test)")
plot_pacf(residual_series, lags=20, ax=axes[1], alpha=0.05, method='ywm')
axes[1].set_title("PACF of XGBoost Residuals (OOF train + OOS test)")
plt.tight_layout()
plt.show()

# ── Identify statistically significant lags (ACF) ────────────────────────────
n_lags = 20
threshold = 1.959964 / np.sqrt(N)  # standard 95% approx. bound for white noise
acf_vals = acf_fn(residual_series, nlags=n_lags, fft=False)

print(f"N = {N} residuals | 95% significance threshold: |ACF| > {threshold:.4f}\n")
print("Lag | ACF value | Significant?")
significant_lags = []
for lag in range(1, n_lags + 1):
    is_sig = abs(acf_vals[lag]) > threshold
    marker = "  <-- significant" if is_sig else ""
    print(f"{lag:>3} | {acf_vals[lag]:>9.4f} |{marker}")
    if is_sig:
        significant_lags.append(lag)

print(f"\nStatistically significant lags (95% level): {significant_lags}")

# ── Ljung-Box test: are residuals jointly autocorrelated up to lag k? ───────
lb_test = acorr_ljungbox(residual_series, lags=[5, 10, 20], return_df=True)
print("\nLjung-Box test (H0: no autocorrelation up to the given lag):")
print(lb_test)
print("\n(A p-value below 0.05 rejects H0 -- i.e. there IS significant "
      "autocorrelation up to that lag.)")
# Out:
# N = 3478 residuals | 95% significance threshold: |ACF| > 0.0332
#
# Lag | ACF value | Significant?
#   1 |    0.1170 |  <-- significant
#   2 |   -0.0425 |  <-- significant
#   3 |   -0.0110 |
#   4 |   -0.0197 |
#   5 |    0.0055 |
#   6 |   -0.0109 |
#   7 |    0.0126 |
#   8 |    0.0211 |
#   9 |    0.0419 |  <-- significant
#  10 |    0.0376 |  <-- significant
#  11 |    0.0340 |  <-- significant
#  12 |    0.0072 |
#  13 |    0.0100 |
#  14 |    0.0087 |
#  15 |    0.0444 |  <-- significant
#  16 |   -0.0038 |
#  17 |    0.0075 |
#  18 |    0.0302 |
#  19 |    0.0262 |
#  20 |    0.0258 |
#
# Statistically significant lags (95% level): [1, 2, 9, 10, 11, 15]
#
# Ljung-Box test (H0: no autocorrelation up to the given lag):
#       lb_stat     lb_pvalue
# 5   55.826496  8.823323e-11
# 10  69.389684  5.815016e-11
# 20  89.284626  9.884496e-11
#
# (A p-value below 0.05 rejects H0 -- i.e. there IS significant autocorrelation up to that lag.)

# %% [markdown]
# ## 10. CNN Residual Correction Model -- Data Preparation

# %%
# =============================================================================
# RESIDUAL CORRECTION MODEL — feature set for CNN
# -----------------------------------------------------------------------------
# Adds two new engineered features: Residual_lag1, Residual_lag2 -- the
# previous 1 and 2 days' OOF (train) / out-of-sample (test) XGBoost
# residuals. The ACF/PACF diagnostics above (Section 9) are used to decide
# whether these lags carry real signal; the features are included here so
# the CNN can exploit residual autocorrelation that the exogenous features
# alone cannot capture, since the CNN otherwise sees the same information
# XGBoost already used.
#
# WHY THIS IS NOT LEAKAGE: at forecast time for day t, the actual wind speed
# (and hence residual) for day t-1 and t-2 has already been observed -- these
# are genuine past values, not information from the future or from the row
# being predicted itself.
#
# Train rows: restricted to those with a valid OUT-OF-FOLD residual (see
#   Section 7). The initial training block with no OOF coverage is dropped.
# Test rows: unchanged -- always genuinely out-of-sample.
# =============================================================================

df['Residual_lag1'] = df['Residual'].shift(1)
df['Residual_lag2'] = df['Residual'].shift(2)

# NOTE: df_backup was already snapshotted (df_backup = df.copy()) back in
# Section 8, BEFORE these two lag columns existed on df -- so df_backup is
# missing them unless we sync them across explicitly here. Every downstream
# section reads df_backup (not df) when saving the per-model CSV export via
# `df_backup[cnn_features + [...]]`, which would otherwise raise
# `KeyError: ['Residual_lag1', 'Residual_lag2'] not in index`.
df_backup['Residual_lag1'] = df['Residual_lag1']
df_backup['Residual_lag2'] = df['Residual_lag2']

cnn_features = [
    'Residual_lag1', 'Residual_lag2'    # NEW: autoregressive residual features
]

X_res = df[cnn_features]  # Features for residual correction
y_res = df['Residual']    # Target: OOF (train) / out-of-sample (test) XGBoost residuals

# Same 80 / 20 temporal split index as the primary model
split_index_res = int(len(X_res) * 0.8)

X_train_res_full = X_res.iloc[:split_index_res]
y_train_res_full = y_res.iloc[:split_index_res]
X_test_res        = X_res.iloc[split_index_res:]
y_test_res         = y_res.iloc[split_index_res:]

# ── Drop rows with any NaN feature or target ─────────────────────────────────
# Two independent sources of NaN now exist:
#   1. Fold 1 of TimeSeriesSplit(n_splits=5) has no preceding validation
#      block, so its training rows were never given an OOF residual
#      (Section 7) -- this affects y_train_res_full AND, via the .shift()
#      above, the Residual_lag1 / Residual_lag2 columns of the rows right
#      after that gap.
#   2. The very first 1-2 rows of the entire series have no lag-1/lag-2
#      residual to look back on.
# Filling either with a synthetic value would fabricate information or
# quietly leak, so these rows are dropped instead. Test rows are expected to
# lose none (their lag features look back into the already-valid tail of the
# training period), but the same check is applied for correctness.
train_valid_mask = X_train_res_full.notna().all(axis=1) & y_train_res_full.notna()
test_valid_mask  = X_test_res.notna().all(axis=1)       & y_test_res.notna()

X_train_res = X_train_res_full.loc[train_valid_mask]
y_train_res = y_train_res_full.loc[train_valid_mask]
X_test_res  = X_test_res.loc[test_valid_mask]
y_test_res  = y_test_res.loc[test_valid_mask]

n_dropped_train = int((~train_valid_mask).sum())
n_dropped_test  = int((~test_valid_mask).sum())

print(f"CNN residual correction -- training rows dropped (no OOF residual "
      f"and/or lag feature): {n_dropped_train}")
print(f"CNN residual correction -- training samples used  : {X_train_res.shape[0]}")
print(f"CNN residual correction -- test samples            : {X_test_res.shape[0]} "
      f"(dropped {n_dropped_test} rows with a missing lag feature)")
print(f"Number of input features                            : {X_train_res.shape[1]}")
# Out:
# CNN residual correction -- training rows dropped (no OOF residual and/or lag feature): 539
# CNN residual correction -- training samples used  : 2673
# CNN residual correction -- test samples            : 803 (dropped 0 rows with a missing lag feature)
# Number of input features                            : 2

# %% [markdown]
# ## 11. CNN Residual Correction — Original Model (No Hyperparameter Optimisation)

# %%
# =============================================================================
# Section 1 — Original CNN model
# Default architecture: Conv1D (64 filters) → Flatten → Dense(50) → Dense(1).
# No hyperparameter search is performed in this section.
# Scaling is fit on training data only to prevent data leakage.
# =============================================================================

# ── Scaling (fit on training data only — no leakage) ─────────────────────────
scaler_original      = StandardScaler()
X_train_sc_orig      = scaler_original.fit_transform(X_train_res)
X_test_sc_orig       = scaler_original.transform(X_test_res)

# ── Reshape to Conv1D format: (samples, timesteps=1, features) ───────────────
X_train_cnn_orig     = np.expand_dims(X_train_sc_orig, axis=1)
X_test_cnn_orig      = np.expand_dims(X_test_sc_orig,  axis=1)
y_train_cnn_orig     = y_train_res.values
y_test_cnn_orig      = y_test_res.values

# ── Build CNN model ───────────────────────────────────────────────────────────
tf.random.set_seed(RANDOM_SEED)
model_orig = Sequential([
    # Conv1D expects input shape = (timesteps, features)
    Conv1D(filters=64, kernel_size=1, activation='relu',
           input_shape=(X_train_cnn_orig.shape[1], X_train_cnn_orig.shape[2])),
    Flatten(),           # Flatten before Dense layers
    Dense(50, activation='relu'),
    Dense(1)             # Regression output layer
])
model_orig.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Fit on training residuals only (validation_split uses last 20% of train
# chronologically — no test-set leakage)
history_orig = model_orig.fit(
    X_train_cnn_orig, y_train_cnn_orig,
    epochs=100,
    batch_size=32,
    validation_split=0.2,   # Uses last 20% of training data as validation
    verbose=1,
    shuffle=False            # Preserve temporal order
)

# ── Residual model evaluation ─────────────────────────────────────────────────
y_train_pred_orig = model_orig.predict(X_train_cnn_orig).flatten()
y_test_pred_orig  = model_orig.predict(X_test_cnn_orig).flatten()

print("\n--- Original CNN Residual Model Evaluation ---")
evaluate(y_train_cnn_orig, y_train_pred_orig, label="Train (CNN Original)")
evaluate(y_test_cnn_orig,  y_test_pred_orig,  label="Test  (CNN Original)")

# Plot residual predictions on test set
plt.figure(figsize=(10, 6))
plt.plot(y_test_cnn_orig,  label='Actual Residuals',  color='black', linewidth=2)
plt.plot(y_test_pred_orig, label='Predicted Residuals (CNN Original)',
         color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Residuals — Test Set (Original CNN)')
plt.xlabel('Sample Index')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ── Predict residuals on the FULL dataset ────────────────────────────────────
# NOTE: X_res (unlike X_train_res/X_test_res) is NOT pre-filtered for NaNs --
# it still contains the rows Section 10 dropped (Fold 1's OOF-uncovered
# training block, plus the first 1-2 rows with no Residual_lag1/lag2 to look
# back on). The CNN can't handle NaN input, so we predict only on the rows
# where every feature is valid, and leave the rest as NaN -- consistent with
# 'Pred_XGB_Optuna' already being NaN for those same rows.
full_valid_mask = X_res.notna().all(axis=1)
X_full_sc_valid  = scaler_original.transform(X_res.loc[full_valid_mask])
X_full_cnn_valid = np.expand_dims(X_full_sc_valid, axis=1)

predicted_residuals_cnn_original_arr = np.full(len(X_res), np.nan)
predicted_residuals_cnn_original_arr[full_valid_mask.values] = model_orig.predict(X_full_cnn_valid).flatten()
print(f"Full-dataset residual predictions: {int(full_valid_mask.sum())} / "
      f"{len(X_res)} rows (NaN elsewhere -- missing lag feature(s))")

df_backup['predicted_residuals_cnn_original'] = predicted_residuals_cnn_original_arr

# ── Hybrid prediction: XGB + CNN residual correction ─────────────────────────
# FIX: original code used 'Pred_XGB_Optuna ' (trailing space) — corrected here
df_backup['XGB_cnn_Original'] = (df_backup['Pred_XGB_Optuna'] +
                                  df_backup['predicted_residuals_cnn_original'])

# ── Hybrid model train / test performance ────────────────────────────────────
# NOTE: df_backup['XGB_cnn_Original'] is NaN for the initial training block that has no
# OOF residual (Sections 7 & 9) -- Pred_XGB_Optuna is NaN there, so those
# rows must be dropped before computing metrics, otherwise mean_squared_error
# etc. would raise or silently propagate NaN. Test rows are unaffected (they
# were always out-of-sample).
train_df_orig = df_backup.iloc[:split_index_res].copy()
train_df_orig = train_df_orig.dropna(subset=['XGB_cnn_Original'])
test_df_orig  = df_backup.iloc[split_index_res:].copy()

print("\n=== Hybrid XGB-CNN (Original) Performance on WS10M ===")
print(f"(Train metrics computed on {len(train_df_orig)} rows -- initial "
      f"OOF-uncovered block excluded)")
train_metrics_orig = evaluate_performance(
    train_df_orig['WS10M'], train_df_orig['XGB_cnn_Original'], set_name="Train")
test_metrics_orig  = evaluate_performance(
    test_df_orig['WS10M'],  test_df_orig['XGB_cnn_Original'],  set_name="Test")

# ── Visualise test-set hybrid predictions ────────────────────────────────────
test_df_orig.index = pd.to_datetime(test_df_orig.index)
plt.figure(figsize=(14, 7))
plt.plot(test_df_orig.index, test_df_orig['WS10M'],
         label='Actual Wind Speed', color='blue', alpha=0.7, linewidth=1)
plt.plot(test_df_orig.index, test_df_orig['XGB_cnn_Original'],
         label='XGBoost-CNN (Original) Prediction',
         color='red', linestyle='--', alpha=0.7, linewidth=1)
plt.title('Daily Wind Speed: Actual vs Predicted\n(XGBoost-CNN Original Model)',
          fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Save results to CSV
xgb_cnn_original_df = df_backup[cnn_features + ['WS10M', 'XGB_cnn_Original']]
xgb_cnn_original_df.to_csv('xgb_cnn_df_original.csv', index=True)
print("Saved to 'xgb_cnn_df_original.csv'")
# Out:
# Epoch 1/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.5269 - val_loss: 0.5339
# Epoch 2/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5185 - val_loss: 0.5343
# Epoch 3/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5165 - val_loss: 0.5347
# Epoch 4/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5154 - val_loss: 0.5354
# Epoch 5/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5146 - val_loss: 0.5356
# Epoch 6/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5140 - val_loss: 0.5360
# Epoch 7/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5137 - val_loss: 0.5366
# Epoch 8/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5130 - val_loss: 0.5367
# Epoch 9/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5126 - val_loss: 0.5371
# Epoch 10/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5123 - val_loss: 0.5375
# Epoch 11/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5119 - val_loss: 0.5376
# Epoch 12/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5117 - val_loss: 0.5377
# Epoch 13/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5114 - val_loss: 0.5377
# Epoch 14/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5112 - val_loss: 0.5378
# Epoch 15/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5110 - val_loss: 0.5378
# Epoch 16/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5109 - val_loss: 0.5380
# Epoch 17/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5108 - val_loss: 0.5381
# Epoch 18/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5104 - val_loss: 0.5380
# Epoch 19/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5102 - val_loss: 0.5381
# Epoch 20/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5100 - val_loss: 0.5380
# Epoch 21/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5098 - val_loss: 0.5379
# Epoch 22/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5096 - val_loss: 0.5377
# Epoch 23/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5095 - val_loss: 0.5378
# Epoch 24/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5093 - val_loss: 0.5378
# Epoch 25/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5092 - val_loss: 0.5378
# Epoch 26/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5090 - val_loss: 0.5378
# Epoch 27/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5089 - val_loss: 0.5379
# Epoch 28/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5088 - val_loss: 0.5380
# Epoch 29/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5086 - val_loss: 0.5380
# Epoch 30/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5085 - val_loss: 0.5380
# Epoch 31/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5084 - val_loss: 0.5380
# Epoch 32/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5083 - val_loss: 0.5381
# Epoch 33/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5081 - val_loss: 0.5381
# Epoch 34/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5080 - val_loss: 0.5380
# Epoch 35/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5079 - val_loss: 0.5381
# Epoch 36/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5078 - val_loss: 0.5382
# Epoch 37/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5077 - val_loss: 0.5381
# Epoch 38/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5076 - val_loss: 0.5382
# Epoch 39/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5075 - val_loss: 0.5380
# Epoch 40/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5074 - val_loss: 0.5384
# Epoch 41/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5071 - val_loss: 0.5384
# Epoch 42/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5070 - val_loss: 0.5382
# Epoch 43/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5069 - val_loss: 0.5384
# Epoch 44/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5068 - val_loss: 0.5386
# Epoch 45/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5067 - val_loss: 0.5386
# Epoch 46/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5067 - val_loss: 0.5388
# Epoch 47/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5065 - val_loss: 0.5390
# Epoch 48/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5064 - val_loss: 0.5390
# Epoch 49/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5063 - val_loss: 0.5391
# Epoch 50/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5061 - val_loss: 0.5394
# Epoch 51/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5060 - val_loss: 0.5395
# Epoch 52/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5059 - val_loss: 0.5396
# Epoch 53/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5058 - val_loss: 0.5397
# Epoch 54/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5057 - val_loss: 0.5399
# Epoch 55/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5056 - val_loss: 0.5401
# Epoch 56/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5055 - val_loss: 0.5403
# Epoch 57/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5054 - val_loss: 0.5403
# Epoch 58/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5053 - val_loss: 0.5406
# Epoch 59/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5052 - val_loss: 0.5407
# Epoch 60/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5051 - val_loss: 0.5411
# Epoch 61/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5050 - val_loss: 0.5410
# Epoch 62/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5049 - val_loss: 0.5413
# Epoch 63/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5047 - val_loss: 0.5414
# Epoch 64/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5047 - val_loss: 0.5416
# Epoch 65/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5046 - val_loss: 0.5416
# Epoch 66/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5045 - val_loss: 0.5419
# Epoch 67/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5044 - val_loss: 0.5420
# Epoch 68/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5043 - val_loss: 0.5423
# Epoch 69/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5042 - val_loss: 0.5420
# Epoch 70/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5042 - val_loss: 0.5423
# Epoch 71/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5040 - val_loss: 0.5426
# Epoch 72/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5040 - val_loss: 0.5425
# Epoch 73/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5038 - val_loss: 0.5430
# Epoch 74/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5037 - val_loss: 0.5431
# Epoch 75/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5036 - val_loss: 0.5431
# Epoch 76/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5036 - val_loss: 0.5434
# Epoch 77/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5035 - val_loss: 0.5433
# Epoch 78/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5034 - val_loss: 0.5435
# Epoch 79/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5033 - val_loss: 0.5438
# Epoch 80/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5032 - val_loss: 0.5439
# Epoch 81/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5032 - val_loss: 0.5439
# Epoch 82/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5031 - val_loss: 0.5444
# Epoch 83/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5030 - val_loss: 0.5443
# Epoch 84/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5029 - val_loss: 0.5447
# Epoch 85/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5028 - val_loss: 0.5447
# Epoch 86/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5028 - val_loss: 0.5450
# Epoch 87/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5027 - val_loss: 0.5449
# Epoch 88/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5026 - val_loss: 0.5453
# Epoch 89/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5024 - val_loss: 0.5453
# Epoch 90/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5024 - val_loss: 0.5458
# Epoch 91/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5023 - val_loss: 0.5457
# Epoch 92/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5023 - val_loss: 0.5458
# Epoch 93/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5022 - val_loss: 0.5457
# Epoch 94/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5021 - val_loss: 0.5460
# Epoch 95/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5021 - val_loss: 0.5462
# Epoch 96/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5019 - val_loss: 0.5467
# Epoch 97/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5019 - val_loss: 0.5467
# Epoch 98/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5018 - val_loss: 0.5470
# Epoch 99/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5017 - val_loss: 0.5468
# Epoch 100/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5018 - val_loss: 0.5472
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Original CNN Residual Model Evaluation ---
# Train (CNN Original) MSE:  0.5073
# Train (CNN Original) RMSE: 0.7122
# Train (CNN Original) MAE:  0.5448
# Train (CNN Original) MAPE: 166.67%
# Train (CNN Original) R²:   0.0276
# Test  (CNN Original) MSE:  0.5198
# Test  (CNN Original) RMSE: 0.7209
# Test  (CNN Original) MAE:  0.5442
# Test  (CNN Original) MAPE: 166.43%
# Test  (CNN Original) R²:   0.0114
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Full-dataset residual predictions: 3476 / 4015 rows (NaN elsewhere -- missing lag feature(s))
#
# === Hybrid XGB-CNN (Original) Performance on WS10M ===
# (Train metrics computed on 2673 rows -- initial OOF-uncovered block excluded)
#
# --- Train Metrics ---
# RMSE: 0.7122
# MSE:  0.5073
# MAE:  0.5448
# MAPE: 15.2791%
# R²:   0.7987
#
# --- Test Metrics ---
# RMSE: 0.7209
# MSE:  0.5198
# MAE:  0.5442
# MAPE: 14.7741%
# R²:   0.7845
# Saved to 'xgb_cnn_df_original.csv'

# %% [markdown]
# ## 12. CNN Residual Correction — Grid Search Hyperparameter Optimisation

# %%
# =============================================================================
# Section 2 — Grid Search CNN
# Exhaustive grid search over the defined parameter grid.
# TimeSeriesSplit (5 folds) is applied exclusively on the training data.
# Scaling is fit on training data only to prevent data leakage.
#
# FIX vs original code:
#   - Replaced mid-notebook CSV reload (which broke the in-memory pipeline)
#     with the in-memory df_backup object.
#   - Fixed 'Pred_XGB_Optuna ' (trailing space KeyError) → 'Pred_XGB_Optuna'.
# =============================================================================

# ── Scaling (fit on training data only — no leakage) ─────────────────────────
scaler_grid      = StandardScaler()
X_train_sc_grid  = scaler_grid.fit_transform(X_train_res)
X_test_sc_grid   = scaler_grid.transform(X_test_res)

# ── Reshape to Conv1D format: (samples, timesteps=1, features) ───────────────
X_train_cnn_grid = np.expand_dims(X_train_sc_grid, axis=1)
X_test_cnn_grid  = np.expand_dims(X_test_sc_grid,  axis=1)

# ── CNN model builder function (required by KerasRegressor) ──────────────────
def build_cnn_grid(filters=64, kernel_size=1, dropout_rate=0.2, learning_rate=0.001):
    """Builds and compiles a 1-D CNN model for use in GridSearchCV."""
    n_features = X_train_cnn_grid.shape[2]
    mdl = Sequential([
        Conv1D(filters=filters, kernel_size=kernel_size, activation='relu',
               input_shape=(1, n_features)),
        Flatten(),
        Dropout(dropout_rate),
        Dense(50, activation='relu'),
        Dense(1)
    ])
    mdl.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    return mdl

# ── Wrap Keras model for scikit-learn API ─────────────────────────────────────
cnn_regressor_grid = KerasRegressor(
    model=build_cnn_grid, verbose=0, random_state=RANDOM_SEED
)

# ── Parameter grid ────────────────────────────────────────────────────────────
param_grid = {
    'model__filters':       [32, 64, 128],
    'model__dropout_rate':  [0.1, 0.2, 0.3],
    'model__learning_rate': [1e-2, 1e-3, 1e-4],
    'batch_size':           [16, 32],
    'epochs':               [50, 100]
}

# ── Time series cross-validation (training data only) ────────────────────────
tscv_grid = TimeSeriesSplit(n_splits=5)

grid_search = GridSearchCV(
    estimator=cnn_regressor_grid,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=tscv_grid,           # TimeSeriesSplit preserves temporal ordering
    verbose=2,
    n_jobs=1                # Sequential — parallelism with TF can cause issues
)

# Fit grid search on training data only
grid_search.fit(X_train_cnn_grid, y_train_res.values)

best_cnn_grid = grid_search.best_estimator_
print("\nBest Parameters (Grid Search):")
print(grid_search.best_params_)

# ── Residual model evaluation ─────────────────────────────────────────────────
y_train_pred_grid = best_cnn_grid.predict(X_train_cnn_grid).flatten()
y_test_pred_grid  = best_cnn_grid.predict(X_test_cnn_grid).flatten()

print("\n--- Grid Search CNN Residual Model Evaluation ---")
evaluate(y_train_res.values, y_train_pred_grid, label="Train (CNN Grid Search)")
evaluate(y_test_res.values,  y_test_pred_grid,  label="Test  (CNN Grid Search)")

# Plot residual predictions on test set
plt.figure(figsize=(10, 6))
plt.plot(y_test_res.values, label='Actual Residuals',   color='black', linewidth=2)
plt.plot(y_test_pred_grid,  label='Predicted Residuals (Grid Search)',
         color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Residuals — Test Set (Grid Search CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# ── Predict residuals on the FULL dataset ────────────────────────────────────
# NOTE: X_res (unlike X_train_res/X_test_res) is NOT pre-filtered for NaNs --
# it still contains the rows Section 10 dropped (Fold 1's OOF-uncovered
# training block, plus the first 1-2 rows with no Residual_lag1/lag2 to look
# back on). The CNN can't handle NaN input, so we predict only on the rows
# where every feature is valid, and leave the rest as NaN -- consistent with
# 'Pred_XGB_Optuna' already being NaN for those same rows.
full_valid_mask = X_res.notna().all(axis=1)
X_full_sc_valid  = scaler_grid.transform(X_res.loc[full_valid_mask])
X_full_cnn_valid = np.expand_dims(X_full_sc_valid, axis=1)

predicted_residuals_cnn_grid_arr = np.full(len(X_res), np.nan)
predicted_residuals_cnn_grid_arr[full_valid_mask.values] = best_cnn_grid.predict(X_full_cnn_valid).flatten()
print(f"Full-dataset residual predictions: {int(full_valid_mask.sum())} / "
      f"{len(X_res)} rows (NaN elsewhere -- missing lag feature(s))")

df_backup['predicted_residuals_cnn_grid'] = predicted_residuals_cnn_grid_arr

# ── Hybrid prediction: XGB + CNN residual correction ─────────────────────────
df_backup['XGB_cnn_grid'] = (df_backup['Pred_XGB_Optuna'] +
                              df_backup['predicted_residuals_cnn_grid'])

# ── Hybrid model train / test performance ────────────────────────────────────
# NOTE: df_backup['XGB_cnn_grid'] is NaN for the initial training block that has no
# OOF residual (Sections 7 & 9) -- Pred_XGB_Optuna is NaN there, so those
# rows must be dropped before computing metrics, otherwise mean_squared_error
# etc. would raise or silently propagate NaN. Test rows are unaffected (they
# were always out-of-sample).
train_df_grid = df_backup.iloc[:split_index_res].copy()
train_df_grid = train_df_grid.dropna(subset=['XGB_cnn_grid'])
test_df_grid  = df_backup.iloc[split_index_res:].copy()

print("\n=== Hybrid XGB-CNN (Grid Search) Performance on WS10M ===")
print(f"(Train metrics computed on {len(train_df_grid)} rows -- initial "
      f"OOF-uncovered block excluded)")
train_metrics_grid = evaluate_performance(
    train_df_grid['WS10M'], train_df_grid['XGB_cnn_grid'], set_name="Train")
test_metrics_grid  = evaluate_performance(
    test_df_grid['WS10M'],  test_df_grid['XGB_cnn_grid'],  set_name="Test")

# ── Visualise test-set hybrid predictions ────────────────────────────────────
test_df_grid.index = pd.to_datetime(test_df_grid.index)
plt.figure(figsize=(14, 7))
plt.plot(test_df_grid.index, test_df_grid['WS10M'],
         label='Actual Wind Speed', color='blue', alpha=0.7, linewidth=1)
plt.plot(test_df_grid.index, test_df_grid['XGB_cnn_grid'],
         label='XGBoost-CNN (Grid Search) Prediction',
         color='red', linestyle='--', alpha=0.7, linewidth=1)
plt.title('Daily Wind Speed: Actual vs Predicted\n(XGBoost-CNN Grid Search Model)',
          fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Save results to CSV
xgb_cnn_df_grid = df_backup[cnn_features + ['WS10M', 'XGB_cnn_grid']]
xgb_cnn_df_grid.to_csv('xgb_cnn_df_grid.csv', index=True)
print("Saved to 'xgb_cnn_df_grid.csv'")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  10.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  11.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  15.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  17.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   7.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   8.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  15.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  20.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  21.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   5.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   9.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  13.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  15.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  17.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   6.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   9.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  13.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  15.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  17.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   6.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   9.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  11.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  15.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  17.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   5.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   9.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  12.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  16.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  19.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   5.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  10.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  12.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  19.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   5.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  10.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  12.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  15.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   5.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  10.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  12.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  19.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   6.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  10.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  13.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  17.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   6.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   9.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  12.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  14.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  17.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   6.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   8.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  12.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   5.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   9.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  12.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  14.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  18.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   5.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  10.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  12.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  17.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  19.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   6.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  10.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  13.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  15.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  19.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   5.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  10.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  13.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  15.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  19.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   6.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  10.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  13.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  15.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  19.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   5.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  10.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  12.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  19.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   5.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   9.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  12.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  14.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  20.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   6.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  10.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  12.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  15.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  18.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   6.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  10.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  12.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  17.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   7.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  10.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  13.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  15.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  18.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=   7.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  10.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  13.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  15.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  18.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=   7.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  10.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  12.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  17.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=   6.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=   9.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  13.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  18.8s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  20.6s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=   6.3s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  10.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  13.5s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  15.9s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  20.1s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=   6.0s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  10.2s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  13.4s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  15.7s
# [CV] END batch_size=16, epochs=50, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  19.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  11.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  17.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  23.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  29.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  36.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  11.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  23.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  29.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  34.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  11.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  17.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  23.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  30.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  34.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  11.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  18.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  22.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  29.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  33.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  11.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  18.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  22.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  33.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  37.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  12.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  18.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  24.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  31.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  34.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  11.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  23.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  29.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  34.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  11.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  18.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  23.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  30.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  36.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  11.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  18.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  24.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  29.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  36.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  11.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  17.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  23.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  28.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  35.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  11.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  17.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  23.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  29.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  35.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  11.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  24.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  29.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  36.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  10.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  24.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  31.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  47.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  13.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  20.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  26.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  31.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  37.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  11.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  17.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  23.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  29.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  37.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  11.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  18.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  23.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  29.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  34.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  10.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  19.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  24.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  28.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  36.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  11.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  17.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  23.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  28.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  35.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  11.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  17.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  23.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  28.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  34.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  11.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  16.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  23.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  28.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  34.1s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  10.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  17.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  23.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  28.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  35.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  11.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  16.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  23.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  28.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  34.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  11.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  23.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  35.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  37.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  12.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  18.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  25.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  29.7s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  35.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  11.9s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  18.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  23.6s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  30.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  36.5s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  10.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  18.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  25.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  30.2s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  38.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  11.8s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  19.3s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  23.0s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  30.4s
# [CV] END batch_size=16, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  36.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   4.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.01; total time=  11.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   4.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=   9.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.001; total time=  11.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   4.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   8.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=32, model__learning_rate=0.0001; total time=  11.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   5.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   6.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=   9.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  10.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   5.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   6.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   8.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  11.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   4.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   6.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  11.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   4.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   7.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  10.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  17.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   5.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   8.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  10.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  12.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   6.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   6.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  10.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  11.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   4.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   6.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   8.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=   9.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  11.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   4.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   7.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   7.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  10.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  11.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   4.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   7.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   7.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  11.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   4.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   8.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  11.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   5.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   6.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   9.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  10.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   5.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   6.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   8.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   9.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  10.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   5.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   6.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   8.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  11.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   4.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   7.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  10.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  11.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   4.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   7.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   9.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  10.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  10.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   5.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   6.2s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   8.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   9.7s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  10.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   4.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   6.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  10.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  11.1s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  11.8s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   7.4s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   9.6s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  10.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  12.3s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   5.0s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=32, epochs=50, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   8.4s
# ...
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  19.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.01; total time=  20.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=   9.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  12.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  19.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.001; total time=  20.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=   9.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  12.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  15.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  19.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=64, model__learning_rate=0.0001; total time=  20.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=   9.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  12.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  15.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  18.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.01; total time=  20.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=   9.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  12.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  19.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.001; total time=  20.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=   9.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  15.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  28.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.1, model__filters=128, model__learning_rate=0.0001; total time=  25.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  10.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  13.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  15.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  19.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.01; total time=  22.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  12.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  16.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  17.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.001; total time=  21.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=   8.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  12.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  18.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=32, model__learning_rate=0.0001; total time=  20.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=   8.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  12.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  14.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  18.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.01; total time=  20.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=   9.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  12.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  14.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  18.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.001; total time=  19.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  12.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  14.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  17.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=64, model__learning_rate=0.0001; total time=  21.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=   9.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  12.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  15.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  18.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.01; total time=  21.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=   9.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  15.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  17.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.001; total time=  21.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=   9.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  18.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.2, model__filters=128, model__learning_rate=0.0001; total time=  22.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=   9.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  12.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  17.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.01; total time=  21.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=   8.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  12.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  17.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.001; total time=  20.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=   8.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  11.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  15.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  17.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=32, model__learning_rate=0.0001; total time=  20.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=   7.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  12.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  15.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  18.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.01; total time=  20.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=   8.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  12.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  14.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  19.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.001; total time=  20.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=   8.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  12.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  18.7s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=64, model__learning_rate=0.0001; total time=  19.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=   9.2s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  12.4s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  15.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  19.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.01; total time=  20.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=   9.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  12.6s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  14.9s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  19.1s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.001; total time=  20.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=   9.3s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  12.0s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  14.5s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  17.8s
# [CV] END batch_size=32, epochs=100, model__dropout_rate=0.3, model__filters=128, model__learning_rate=0.0001; total time=  21.7s
#
# Best Parameters (Grid Search):
# {'batch_size': 16, 'epochs': 50, 'model__dropout_rate': 0.2, 'model__filters': 64, 'model__learning_rate': 0.0001}
#
# --- Grid Search CNN Residual Model Evaluation ---
# Train (CNN Grid Search) MSE:  0.5102
# Train (CNN Grid Search) RMSE: 0.7143
# Train (CNN Grid Search) MAE:  0.5480
# Train (CNN Grid Search) MAPE: 181.00%
# Train (CNN Grid Search) R²:   0.0220
# Test  (CNN Grid Search) MSE:  0.5219
# Test  (CNN Grid Search) RMSE: 0.7224
# Test  (CNN Grid Search) MAE:  0.5455
# Test  (CNN Grid Search) MAPE: 154.81%
# Test  (CNN Grid Search) R²:   0.0074
# Full-dataset residual predictions: 3476 / 4015 rows (NaN elsewhere -- missing lag feature(s))
#
# === Hybrid XGB-CNN (Grid Search) Performance on WS10M ===
# (Train metrics computed on 2673 rows -- initial OOF-uncovered block excluded)
#
# --- Train Metrics ---
# RMSE: 0.7143
# MSE:  0.5102
# MAE:  0.5480
# MAPE: 15.2379%
# R²:   0.7976
#
# --- Test Metrics ---
# RMSE: 0.7224
# MSE:  0.5219
# MAE:  0.5455
# MAPE: 14.6791%
# R²:   0.7836
# Saved to 'xgb_cnn_df_grid.csv'

# %% [markdown]
# ## 13. CNN Residual Correction — Randomized Search Hyperparameter Optimisation

# %%
# =============================================================================
# Section 3 — Randomized Search CNN
# Random sampling over hyperparameter distributions (10 iterations).
# TimeSeriesSplit (5 folds) is applied exclusively on training data.
# Scaling is fit on training data only to prevent data leakage.
#
# FIX vs original code:
#   - Replaced cv=3 (standard K-Fold, shuffles data) with
#     TimeSeriesSplit(n_splits=5) to respect temporal ordering.
#   - Fixed 'Pred_XGB_Optuna ' (trailing space KeyError) → 'Pred_XGB_Optuna'.
#   - param_dist keys corrected to use 'model__' prefix required by scikeras.
# =============================================================================

# ── Scaling (fit on training data only — no leakage) ─────────────────────────
scaler_random     = StandardScaler()
X_train_sc_rand   = scaler_random.fit_transform(X_train_res)
X_test_sc_rand    = scaler_random.transform(X_test_res)

# ── Reshape to Conv1D format: (samples, timesteps=1, features) ───────────────
X_train_cnn_rand  = np.expand_dims(X_train_sc_rand, axis=1)
X_test_cnn_rand   = np.expand_dims(X_test_sc_rand,  axis=1)

# ── CNN model builder function (required by KerasRegressor) ──────────────────
def create_cnn_random(filters=64, dropout_rate=0.2, learning_rate=0.001):
    """Builds and compiles a 1-D CNN model for use in RandomizedSearchCV."""
    n_features = X_train_cnn_rand.shape[2]
    mdl = Sequential([
        Conv1D(filters=filters, kernel_size=1, activation='relu',
               input_shape=(1, n_features)),
        Flatten(),
        Dropout(dropout_rate),
        Dense(50, activation='relu'),
        Dense(1)    # Regression output
    ])
    mdl.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    return mdl

# ── Wrap Keras model for scikit-learn API ─────────────────────────────────────
cnn_regressor_rand = KerasRegressor(
    model=create_cnn_random, verbose=0, random_state=RANDOM_SEED
)

# ── Hyperparameter distributions ─────────────────────────────────────────────
param_dist = {
    'model__filters':       randint(20, 151),
    'model__dropout_rate':  uniform(0.1, 0.3),
    'model__learning_rate': uniform(1e-4, 9e-3),
    'batch_size':           randint(16, 65),
    'epochs':               randint(50, 151)
}

# ── Time series cross-validation (training data only) ────────────────────────
tscv_rand = TimeSeriesSplit(n_splits=5)

random_search = RandomizedSearchCV(
    estimator=cnn_regressor_rand,
    param_distributions=param_dist,
    n_iter=10,
    scoring='neg_mean_squared_error',
    cv=tscv_rand,           # TimeSeriesSplit preserves temporal ordering
    random_state=RANDOM_SEED,
    verbose=2,
    n_jobs=1                # Sequential — parallelism with TF can cause issues
)

# Fit randomized search on training data only
random_search.fit(X_train_cnn_rand, y_train_res.values)

best_cnn_rand = random_search.best_estimator_
print("\nBest Parameters (Randomized Search):")
print(random_search.best_params_)

# ── Residual model evaluation ─────────────────────────────────────────────────
y_train_pred_rand = best_cnn_rand.predict(X_train_cnn_rand).flatten()
y_test_pred_rand  = best_cnn_rand.predict(X_test_cnn_rand).flatten()

print("\n--- Randomized Search CNN Residual Model Evaluation ---")
evaluate(y_train_res.values, y_train_pred_rand, label="Train (CNN Randomized Search)")
evaluate(y_test_res.values,  y_test_pred_rand,  label="Test  (CNN Randomized Search)")

# Plot residual predictions on test set
plt.figure(figsize=(10, 6))
plt.plot(y_test_res.values, label='Actual Residuals',   color='black', linewidth=2)
plt.plot(y_test_pred_rand,  label='Predicted Residuals (Randomized Search)',
         color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Residuals — Test Set (Randomized Search CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# ── Predict residuals on the FULL dataset ────────────────────────────────────
# NOTE: X_res (unlike X_train_res/X_test_res) is NOT pre-filtered for NaNs --
# it still contains the rows Section 10 dropped (Fold 1's OOF-uncovered
# training block, plus the first 1-2 rows with no Residual_lag1/lag2 to look
# back on). The CNN can't handle NaN input, so we predict only on the rows
# where every feature is valid, and leave the rest as NaN -- consistent with
# 'Pred_XGB_Optuna' already being NaN for those same rows.
full_valid_mask = X_res.notna().all(axis=1)
X_full_sc_valid  = scaler_random.transform(X_res.loc[full_valid_mask])
X_full_cnn_valid = np.expand_dims(X_full_sc_valid, axis=1)

predicted_residuals_cnn_random_arr = np.full(len(X_res), np.nan)
predicted_residuals_cnn_random_arr[full_valid_mask.values] = best_cnn_rand.predict(X_full_cnn_valid).flatten()
print(f"Full-dataset residual predictions: {int(full_valid_mask.sum())} / "
      f"{len(X_res)} rows (NaN elsewhere -- missing lag feature(s))")

df_backup['predicted_residuals_cnn_random'] = predicted_residuals_cnn_random_arr

# ── Hybrid prediction: XGB + CNN residual correction ─────────────────────────
df_backup['XGB_cnn_random'] = (df_backup['Pred_XGB_Optuna'] +
                                df_backup['predicted_residuals_cnn_random'])

# ── Hybrid model train / test performance ────────────────────────────────────
# NOTE: df_backup['XGB_cnn_random'] is NaN for the initial training block that has no
# OOF residual (Sections 7 & 9) -- Pred_XGB_Optuna is NaN there, so those
# rows must be dropped before computing metrics, otherwise mean_squared_error
# etc. would raise or silently propagate NaN. Test rows are unaffected (they
# were always out-of-sample).
train_df_rand = df_backup.iloc[:split_index_res].copy()
train_df_rand = train_df_rand.dropna(subset=['XGB_cnn_random'])
test_df_rand  = df_backup.iloc[split_index_res:].copy()

print("\n=== Hybrid XGB-CNN (Randomized Search) Performance on WS10M ===")
print(f"(Train metrics computed on {len(train_df_rand)} rows -- initial "
      f"OOF-uncovered block excluded)")
train_metrics_rand = evaluate_performance(
    train_df_rand['WS10M'], train_df_rand['XGB_cnn_random'], set_name="Train")
test_metrics_rand  = evaluate_performance(
    test_df_rand['WS10M'],  test_df_rand['XGB_cnn_random'],  set_name="Test")

# ── Visualise test-set hybrid predictions ────────────────────────────────────
test_df_rand.index = pd.to_datetime(test_df_rand.index)
plt.figure(figsize=(14, 7))
plt.plot(test_df_rand.index, test_df_rand['WS10M'],
         label='Actual Wind Speed', color='blue', alpha=0.7, linewidth=1)
plt.plot(test_df_rand.index, test_df_rand['XGB_cnn_random'],
         label='XGBoost-CNN (Randomized Search) Prediction',
         color='red', linestyle='--', alpha=0.7, linewidth=1)
plt.title('Daily Wind Speed: Actual vs Predicted\n(XGBoost-CNN Randomized Search Model)',
          fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Save results to CSV
xgb_cnn_df_random = df_backup[cnn_features + ['WS10M', 'XGB_cnn_random']]
xgb_cnn_df_random.to_csv('xgb_cnn_df_random.csv', index=True)
print("Saved to 'xgb_cnn_df_random.csv'")
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END batch_size=54, epochs=101, model__dropout_rate=0.38521429192297485, model__filters=126, model__learning_rate=0.007117219002454924; total time=   9.0s
# [CV] END batch_size=54, epochs=101, model__dropout_rate=0.38521429192297485, model__filters=126, model__learning_rate=0.007117219002454924; total time=  11.5s
# [CV] END batch_size=54, epochs=101, model__dropout_rate=0.38521429192297485, model__filters=126, model__learning_rate=0.007117219002454924; total time=  13.0s
# [CV] END batch_size=54, epochs=101, model__dropout_rate=0.38521429192297485, model__filters=126, model__learning_rate=0.007117219002454924; total time=  14.7s
# [CV] END batch_size=54, epochs=101, model__dropout_rate=0.38521429192297485, model__filters=126, model__learning_rate=0.007117219002454924; total time=  17.1s
# [CV] END batch_size=36, epochs=132, model__dropout_rate=0.12999247474540088, model__filters=107, model__learning_rate=0.003103377500251196; total time=  12.1s
# [CV] END batch_size=36, epochs=132, model__dropout_rate=0.12999247474540088, model__filters=107, model__learning_rate=0.003103377500251196; total time=  15.3s
# [CV] END batch_size=36, epochs=132, model__dropout_rate=0.12999247474540088, model__filters=107, model__learning_rate=0.003103377500251196; total time=  19.1s
# [CV] END batch_size=36, epochs=132, model__dropout_rate=0.12999247474540088, model__filters=107, model__learning_rate=0.003103377500251196; total time=  23.0s
# [CV] END batch_size=36, epochs=132, model__dropout_rate=0.12999247474540088, model__filters=107, model__learning_rate=0.003103377500251196; total time=  25.7s
# [CV] END batch_size=55, epochs=73, model__dropout_rate=0.29526654188465584, model__filters=72, model__learning_rate=0.008829188669457947; total time=   7.2s
# [CV] END batch_size=55, epochs=73, model__dropout_rate=0.29526654188465584, model__filters=72, model__learning_rate=0.008829188669457947; total time=   7.2s
# [CV] END batch_size=55, epochs=73, model__dropout_rate=0.29526654188465584, model__filters=72, model__learning_rate=0.008829188669457947; total time=   9.5s
# [CV] END batch_size=55, epochs=73, model__dropout_rate=0.29526654188465584, model__filters=72, model__learning_rate=0.008829188669457947; total time=  10.7s
# [CV] END batch_size=55, epochs=73, model__dropout_rate=0.29526654188465584, model__filters=72, model__learning_rate=0.008829188669457947; total time=  11.6s
# [CV] END batch_size=59, epochs=79, model__dropout_rate=0.16370173320348286, model__filters=40, model__learning_rate=0.005657333586649448; total time=   6.0s
# WARNING:tensorflow:5 out of the last 18 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d2acb2a5f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END batch_size=59, epochs=79, model__dropout_rate=0.16370173320348286, model__filters=40, model__learning_rate=0.005657333586649448; total time=   8.2s
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d2acb9c5f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END batch_size=59, epochs=79, model__dropout_rate=0.16370173320348286, model__filters=40, model__learning_rate=0.005657333586649448; total time=   9.3s
# [CV] END batch_size=59, epochs=79, model__dropout_rate=0.16370173320348286, model__filters=40, model__learning_rate=0.005657333586649448; total time=   9.3s
# [CV] END batch_size=59, epochs=79, model__dropout_rate=0.16370173320348286, model__filters=40, model__learning_rate=0.005657333586649448; total time=  11.6s
# [CV] END batch_size=37, epochs=138, model__dropout_rate=0.18736874205941256, model__filters=78, model__learning_rate=0.0036987487454372987; total time=  12.3s
# [CV] END batch_size=37, epochs=138, model__dropout_rate=0.18736874205941256, model__filters=78, model__learning_rate=0.0036987487454372987; total time=  15.1s
# [CV] END batch_size=37, epochs=138, model__dropout_rate=0.18736874205941256, model__filters=78, model__learning_rate=0.0036987487454372987; total time=  18.8s
# [CV] END batch_size=37, epochs=138, model__dropout_rate=0.18736874205941256, model__filters=78, model__learning_rate=0.0036987487454372987; total time=  22.5s
# [CV] END batch_size=37, epochs=138, model__dropout_rate=0.18736874205941256, model__filters=78, model__learning_rate=0.0036987487454372987; total time=  26.2s
# [CV] END batch_size=43, epochs=109, model__dropout_rate=0.2099085529881075, model__filters=70, model__learning_rate=0.003542157921404464; total time=   8.8s
# [CV] END batch_size=43, epochs=109, model__dropout_rate=0.2099085529881075, model__filters=70, model__learning_rate=0.003542157921404464; total time=  11.5s
# [CV] END batch_size=43, epochs=109, model__dropout_rate=0.2099085529881075, model__filters=70, model__learning_rate=0.003542157921404464; total time=  13.7s
# [CV] END batch_size=43, epochs=109, model__dropout_rate=0.2099085529881075, model__filters=70, model__learning_rate=0.003542157921404464; total time=  16.9s
# [CV] END batch_size=43, epochs=109, model__dropout_rate=0.2099085529881075, model__filters=70, model__learning_rate=0.003542157921404464; total time=  17.9s
# [CV] END batch_size=18, epochs=150, model__dropout_rate=0.28226345557043153, model__filters=40, model__learning_rate=0.004154493267725887; total time=  15.7s
# [CV] END batch_size=18, epochs=150, model__dropout_rate=0.28226345557043153, model__filters=40, model__learning_rate=0.004154493267725887; total time=  23.6s
# [CV] END batch_size=18, epochs=150, model__dropout_rate=0.28226345557043153, model__filters=40, model__learning_rate=0.004154493267725887; total time=  30.2s
# [CV] END batch_size=18, epochs=150, model__dropout_rate=0.28226345557043153, model__filters=40, model__learning_rate=0.004154493267725887; total time=  39.0s
# [CV] END batch_size=18, epochs=150, model__dropout_rate=0.28226345557043153, model__filters=40, model__learning_rate=0.004154493267725887; total time=  44.7s
# [CV] END batch_size=33, epochs=53, model__dropout_rate=0.3826605267054558, model__filters=33, model__learning_rate=0.00737557613304815; total time=   5.1s
# [CV] END batch_size=33, epochs=53, model__dropout_rate=0.3826605267054558, model__filters=33, model__learning_rate=0.00737557613304815; total time=   7.4s
# [CV] END batch_size=33, epochs=53, model__dropout_rate=0.3826605267054558, model__filters=33, model__learning_rate=0.00737557613304815; total time=   9.1s
# [CV] END batch_size=33, epochs=53, model__dropout_rate=0.3826605267054558, model__filters=33, model__learning_rate=0.00737557613304815; total time=   8.8s
# [CV] END batch_size=33, epochs=53, model__dropout_rate=0.3826605267054558, model__filters=33, model__learning_rate=0.00737557613304815; total time=  11.0s
# [CV] END batch_size=24, epochs=139, model__dropout_rate=0.12930163420191515, model__filters=103, model__learning_rate=0.002269229194234105; total time=  13.8s
# [CV] END batch_size=24, epochs=139, model__dropout_rate=0.12930163420191515, model__filters=103, model__learning_rate=0.002269229194234105; total time=  19.8s
# [CV] END batch_size=24, epochs=139, model__dropout_rate=0.12930163420191515, model__filters=103, model__learning_rate=0.002269229194234105; total time=  24.6s
# [CV] END batch_size=24, epochs=139, model__dropout_rate=0.12930163420191515, model__filters=103, model__learning_rate=0.002269229194234105; total time=  29.5s
# [CV] END batch_size=24, epochs=139, model__dropout_rate=0.12930163420191515, model__filters=103, model__learning_rate=0.002269229194234105; total time=  36.2s
# [CV] END batch_size=22, epochs=93, model__dropout_rate=0.24855307303338106, model__filters=54, model__learning_rate=0.008283883618709038; total time=  10.5s
# [CV] END batch_size=22, epochs=93, model__dropout_rate=0.24855307303338106, model__filters=54, model__learning_rate=0.008283883618709038; total time=  13.6s
# [CV] END batch_size=22, epochs=93, model__dropout_rate=0.24855307303338106, model__filters=54, model__learning_rate=0.008283883618709038; total time=  17.4s
# [CV] END batch_size=22, epochs=93, model__dropout_rate=0.24855307303338106, model__filters=54, model__learning_rate=0.008283883618709038; total time=  21.5s
# [CV] END batch_size=22, epochs=93, model__dropout_rate=0.24855307303338106, model__filters=54, model__learning_rate=0.008283883618709038; total time=  25.2s
#
# Best Parameters (Randomized Search):
# {'batch_size': 22, 'epochs': 93, 'model__dropout_rate': np.float64(0.24855307303338106), 'model__filters': 54, 'model__learning_rate': np.float64(0.008283883618709038)}
#
# --- Randomized Search CNN Residual Model Evaluation ---
# Train (CNN Randomized Search) MSE:  0.5175
# Train (CNN Randomized Search) RMSE: 0.7194
# Train (CNN Randomized Search) MAE:  0.5530
# Train (CNN Randomized Search) MAPE: 200.10%
# Train (CNN Randomized Search) R²:   0.0081
# Test  (CNN Randomized Search) MSE:  0.5326
# Test  (CNN Randomized Search) RMSE: 0.7298
# Test  (CNN Randomized Search) MAE:  0.5505
# Test  (CNN Randomized Search) MAPE: 172.65%
# Test  (CNN Randomized Search) R²:   -0.0130
# Full-dataset residual predictions: 3476 / 4015 rows (NaN elsewhere -- missing lag feature(s))
#
# === Hybrid XGB-CNN (Randomized Search) Performance on WS10M ===
# (Train metrics computed on 2673 rows -- initial OOF-uncovered block excluded)
#
# --- Train Metrics ---
# RMSE: 0.7194
# MSE:  0.5175
# MAE:  0.5530
# MAPE: 15.1232%
# R²:   0.7947
#
# --- Test Metrics ---
# RMSE: 0.7298
# MSE:  0.5326
# MAE:  0.5505
# MAPE: 14.5329%
# R²:   0.7791
# Saved to 'xgb_cnn_df_random.csv'

# %% [markdown]
# ## 14. CNN Residual Correction — Optuna Bayesian Optimisation

# %%
# =============================================================================
# Section 4 — Optuna CNN
# Bayesian (TPE) hyperparameter search over architecture and training params.
# TimeSeriesSplit (5 folds) is applied exclusively on training data.
# Scaling is fit on training data only to prevent data leakage.
#
# FIXES vs original code:
#   1. suggest_loguniform() is DEPRECATED in Optuna ≥ 3.x.
#      Replaced with suggest_float('learning_rate', ..., log=True).
#   2. The original code built the CNN model ONCE in create_cnn_model() and
#      called model.fit() multiple times within the CV loop — this accumulates
#      weights across folds (weight leakage between folds).
#      Fixed: a FRESH model is rebuilt for every fold inside the objective.
#   3. Pre-scaled numpy array (X_train_sc_opt) is used throughout the
#      objective so the CNN always sees the same scaled input.
#   4. Fixed 'Pred_XGB_Optuna ' (trailing space KeyError) → 'Pred_XGB_Optuna'.
# =============================================================================

# ── Scaling (fit on training data only — no leakage) ─────────────────────────
scaler_optuna     = StandardScaler()
X_train_sc_opt    = scaler_optuna.fit_transform(X_train_res)
X_test_sc_opt     = scaler_optuna.transform(X_test_res)

# ── Reshape to Conv1D format: (samples, timesteps=1, features) ───────────────
X_train_cnn_opt   = np.expand_dims(X_train_sc_opt, axis=1)
X_test_cnn_opt    = np.expand_dims(X_test_sc_opt,  axis=1)
n_features_opt    = X_train_cnn_opt.shape[2]

# ── Optuna objective function ─────────────────────────────────────────────────
def cnn_objective(trial):
    """
    Objective for Optuna Bayesian optimisation.
    A FRESH model is rebuilt for every cross-validation fold to prevent
    gradient / weight accumulation across folds (weight leakage).
    """
    filters       = trial.suggest_int('filters', 20, 150)
    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size    = trial.suggest_categorical('batch_size', [16, 32, 64])
    epochs        = trial.suggest_int('epochs', 50, 150)

    tscv       = TimeSeriesSplit(n_splits=5)
    mse_scores = []

    for train_idx, val_idx in tscv.split(X_train_cnn_opt):
        # Use pre-scaled numpy slices (no double-scaling / leakage)
        X_t = X_train_cnn_opt[train_idx]
        X_v = X_train_cnn_opt[val_idx]
        y_t = y_train_res.values[train_idx]
        y_v = y_train_res.values[val_idx]

        # Build a FRESH model for each fold to prevent weight accumulation
        tf.random.set_seed(RANDOM_SEED)
        fold_model = Sequential([
            Conv1D(filters=filters, kernel_size=1, activation='relu',
                   input_shape=(1, n_features_opt)),
            Flatten(),
            Dropout(dropout_rate),
            Dense(50, activation='relu'),
            Dense(1)
        ])
        fold_model.compile(loss='mse',
                           optimizer=Adam(learning_rate=learning_rate))
        fold_model.fit(X_t, y_t, epochs=epochs, batch_size=batch_size,
                       verbose=0, shuffle=False)

        preds = fold_model.predict(X_v, verbose=0).flatten()
        mse_scores.append(mean_squared_error(y_v, preds))

    return np.mean(mse_scores)

# ── Create and run Optuna study ───────────────────────────────────────────────
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED)
)
# Max 30 trials or 10 minutes, whichever comes first
study.optimize(cnn_objective, n_trials=30, timeout=600)

print("\nBest Trial:")
print(study.best_trial)
print("\nBest Parameters (Optuna):")
print(study.best_params)

# ── Refit final model on full training data with best parameters ─────────────
best_params_opt = study.best_params

tf.random.set_seed(RANDOM_SEED)
final_model_opt = Sequential([
    Conv1D(filters=best_params_opt['filters'], kernel_size=1, activation='relu',
           input_shape=(1, n_features_opt)),
    Flatten(),
    Dropout(best_params_opt['dropout_rate']),
    Dense(50, activation='relu'),
    Dense(1)
])
final_model_opt.compile(
    loss='mse',
    optimizer=Adam(learning_rate=best_params_opt['learning_rate'])
)
final_model_opt.fit(
    X_train_cnn_opt, y_train_res.values,
    epochs=best_params_opt['epochs'],
    batch_size=best_params_opt['batch_size'],
    verbose=1,
    shuffle=False   # Preserve temporal order
)

# ── Residual model evaluation ─────────────────────────────────────────────────
y_train_pred_opt = final_model_opt.predict(X_train_cnn_opt).flatten()
y_test_pred_opt  = final_model_opt.predict(X_test_cnn_opt).flatten()

print("\n--- Optuna CNN Residual Model Evaluation ---")
evaluate(y_train_res.values, y_train_pred_opt, label="Train (CNN Optuna)")
evaluate(y_test_res.values,  y_test_pred_opt,  label="Test  (CNN Optuna)")

# Plot residual predictions on test set
plt.figure(figsize=(10, 6))
plt.plot(y_test_res.values, label='Actual Residuals', color='black', linewidth=2)
plt.plot(y_test_pred_opt,   label='Predicted Residuals (Optuna)',
         color='blue', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Residuals — Test Set (Optuna CNN)')
plt.xlabel('Observation Index')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# ── Predict residuals on the FULL dataset ────────────────────────────────────
# NOTE: X_res (unlike X_train_res/X_test_res) is NOT pre-filtered for NaNs --
# it still contains the rows Section 10 dropped (Fold 1's OOF-uncovered
# training block, plus the first 1-2 rows with no Residual_lag1/lag2 to look
# back on). The CNN can't handle NaN input, so we predict only on the rows
# where every feature is valid, and leave the rest as NaN -- consistent with
# 'Pred_XGB_Optuna' already being NaN for those same rows.
full_valid_mask = X_res.notna().all(axis=1)
X_full_sc_valid  = scaler_optuna.transform(X_res.loc[full_valid_mask])
X_full_cnn_valid = np.expand_dims(X_full_sc_valid, axis=1)

predicted_residuals_cnn_optuna_arr = np.full(len(X_res), np.nan)
predicted_residuals_cnn_optuna_arr[full_valid_mask.values] = final_model_opt.predict(X_full_cnn_valid).flatten()
print(f"Full-dataset residual predictions: {int(full_valid_mask.sum())} / "
      f"{len(X_res)} rows (NaN elsewhere -- missing lag feature(s))")

df_backup['predicted_residuals_cnn_optuna'] = predicted_residuals_cnn_optuna_arr

# ── Hybrid prediction: XGB + CNN residual correction ─────────────────────────
df_backup['XGB_cnn_optuna'] = (df_backup['Pred_XGB_Optuna'] +
                                df_backup['predicted_residuals_cnn_optuna'])

# ── Hybrid model train / test performance ────────────────────────────────────
# NOTE: df_backup['XGB_cnn_optuna'] is NaN for the initial training block that has no
# OOF residual (Sections 7 & 9) -- Pred_XGB_Optuna is NaN there, so those
# rows must be dropped before computing metrics, otherwise mean_squared_error
# etc. would raise or silently propagate NaN. Test rows are unaffected (they
# were always out-of-sample).
train_df_opt = df_backup.iloc[:split_index_res].copy()
train_df_opt = train_df_opt.dropna(subset=['XGB_cnn_optuna'])
test_df_opt  = df_backup.iloc[split_index_res:].copy()

print("\n=== Hybrid XGB-CNN (Optuna) Performance on WS10M ===")
print(f"(Train metrics computed on {len(train_df_opt)} rows -- initial "
      f"OOF-uncovered block excluded)")
train_metrics_opt = evaluate_performance(
    train_df_opt['WS10M'], train_df_opt['XGB_cnn_optuna'], set_name="Train")
test_metrics_opt  = evaluate_performance(
    test_df_opt['WS10M'],  test_df_opt['XGB_cnn_optuna'],  set_name="Test")

# ── Visualise test-set hybrid predictions ────────────────────────────────────
test_df_opt.index = pd.to_datetime(test_df_opt.index)
plt.figure(figsize=(14, 7))
plt.plot(test_df_opt.index, test_df_opt['WS10M'],
         label='Actual Wind Speed', color='blue', alpha=0.7, linewidth=1)
plt.plot(test_df_opt.index, test_df_opt['XGB_cnn_optuna'],
         label='XGBoost-CNN (Optuna) Prediction',
         color='red', linestyle='--', alpha=0.7, linewidth=1)
plt.title('Daily Wind Speed: Actual vs Predicted\n(XGBoost-CNN Optuna Model)',
          fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Wind Speed (m/s)', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(20))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Save results to CSV
xgb_cnn_df_optuna = df_backup[cnn_features + ['WS10M', 'XGB_cnn_optuna']]
xgb_cnn_df_optuna.to_csv('xgb_cnn_df_optuna.csv', index=True)
print("Saved to 'xgb_cnn_df_optuna.csv'")
# Out:
# Best Trial:
# FrozenTrial(number=6, state=<TrialState.COMPLETE: 1>, values=[0.5315928068849037], datetime_start=datetime.datetime(2026, 8, 2, 5, 51, 5, 576720), datetime_complete=datetime.datetime(2026, 8, 2, 5, 52, 54, 344849), params={'filters': 24, 'dropout_rate': 0.4637281608315128, 'learning_rate': 0.00032927591344236165, 'batch_size': 16, 'epochs': 105}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'filters': IntDistribution(high=150, log=False, low=20, step=1), 'dropout_rate': FloatDistribution(high=0.5, log=False, low=0.1, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'batch_size': CategoricalDistribution(choices=(16, 32, 64)), 'epochs': IntDistribution(high=150, log=False, low=50, step=1)}, trial_id=6, value=None)
#
# Best Parameters (Optuna):
# {'filters': 24, 'dropout_rate': 0.4637281608315128, 'learning_rate': 0.00032927591344236165, 'batch_size': 16, 'epochs': 105}
# Epoch 1/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5444
# Epoch 2/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5301
# Epoch 3/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5232
# Epoch 4/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5241
# Epoch 5/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5189
# Epoch 6/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5160
# Epoch 7/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5210
# Epoch 8/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5158
# Epoch 9/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5205
# Epoch 10/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5150
# Epoch 11/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5164
# Epoch 12/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5146
# Epoch 13/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5155
# Epoch 14/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5124
# Epoch 15/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5157
# Epoch 16/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5157
# Epoch 17/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 18/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5161
# Epoch 19/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5139
# Epoch 20/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 21/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5180
# Epoch 22/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5161
# Epoch 23/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5124
# Epoch 24/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5161
# Epoch 25/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5154
# Epoch 26/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5157
# Epoch 27/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5145
# Epoch 28/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5128
# Epoch 29/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5146
# Epoch 30/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5179
# Epoch 31/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5139
# Epoch 32/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5165
# Epoch 33/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 34/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 35/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 36/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5144
# Epoch 37/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5155
# Epoch 38/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5140
# Epoch 39/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5142
# Epoch 40/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5148
# Epoch 41/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5143
# Epoch 42/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5145
# Epoch 43/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5115
# Epoch 44/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5143
# Epoch 45/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5143
# Epoch 46/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5136
# Epoch 47/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5138
# Epoch 48/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5133
# Epoch 49/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5139
# Epoch 50/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5152
# Epoch 51/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5144
# Epoch 52/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5131
# Epoch 53/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5114
# Epoch 54/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5137
# Epoch 55/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5133
# Epoch 56/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5144
# Epoch 57/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5141
# Epoch 58/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5130
# Epoch 59/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5144
# Epoch 60/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5148
# Epoch 61/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5122
# Epoch 62/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5170
# Epoch 63/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5139
# Epoch 64/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5134
# Epoch 65/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5131
# Epoch 66/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5142
# Epoch 67/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5136
# Epoch 68/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5129
# Epoch 69/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5132
# Epoch 70/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5128
# Epoch 71/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5155
# Epoch 72/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5129
# Epoch 73/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5147
# Epoch 74/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5150
# Epoch 75/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5130
# Epoch 76/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5119
# Epoch 77/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5134
# Epoch 78/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5143
# Epoch 79/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5126
# Epoch 80/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5124
# Epoch 81/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5133
# Epoch 82/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5121
# Epoch 83/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5134
# Epoch 84/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5145
# Epoch 85/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5145
# Epoch 86/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5137
# Epoch 87/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5129
# Epoch 88/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5134
# Epoch 89/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5137
# Epoch 90/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5131
# Epoch 91/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5141
# Epoch 92/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5145
# Epoch 93/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5137
# Epoch 94/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5121
# Epoch 95/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5163
# Epoch 96/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5144
# Epoch 97/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5130
# Epoch 98/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5142
# Epoch 99/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5136
# Epoch 100/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5141
# Epoch 101/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5130
# Epoch 102/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5133
# Epoch 103/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5132
# Epoch 104/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5132
# Epoch 105/105
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5137
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# --- Optuna CNN Residual Model Evaluation ---
# Train (CNN Optuna) MSE:  0.5106
# Train (CNN Optuna) RMSE: 0.7145
# Train (CNN Optuna) MAE:  0.5473
# Train (CNN Optuna) MAPE: 143.50%
# Train (CNN Optuna) R²:   0.0213
# Test  (CNN Optuna) MSE:  0.5172
# Test  (CNN Optuna) RMSE: 0.7192
# Test  (CNN Optuna) MAE:  0.5432
# Test  (CNN Optuna) MAPE: 138.21%
# Test  (CNN Optuna) R²:   0.0162
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Full-dataset residual predictions: 3476 / 4015 rows (NaN elsewhere -- missing lag feature(s))
#
# === Hybrid XGB-CNN (Optuna) Performance on WS10M ===
# (Train metrics computed on 2673 rows -- initial OOF-uncovered block excluded)
#
# --- Train Metrics ---
# RMSE: 0.7145
# MSE:  0.5106
# MAE:  0.5473
# MAPE: 15.2878%
# R²:   0.7974
#
# --- Test Metrics ---
# RMSE: 0.7192
# MSE:  0.5172
# MAE:  0.5432
# MAPE: 14.6938%
# R²:   0.7855
# Saved to 'xgb_cnn_df_optuna.csv'

# %%
# ── Export test-set actuals and predictions for Diebold-Mariano test ─────────
dm_test_df = test_df_opt[['WS10M', 'XGB_cnn_optuna']].copy()
dm_test_df['residuals_XGB_CNN_Optuna'] = dm_test_df['WS10M'] - dm_test_df['XGB_cnn_optuna']
dm_test_df.to_csv('dm_test_xgb_cnn_optuna.csv', index=True)
print("Saved to 'dm_test_xgb_cnn_optuna.csv'")
# Out:
# Saved to 'dm_test_xgb_cnn_optuna.csv'

# %% [markdown]
# ## Check

# %% [markdown]
# ## 15. Comprehensive Performance Comparison Across All Methods

# %%
# =============================================================================
# Summary comparison of all four XGBoost-CNN hybrid model variants.
# Method labels: "Original Model", "Grid Search", "Randomized Search", "Optuna"
# =============================================================================

actual = df_backup['WS10M']

# Map human-readable method names to dataframe column names
methods_map = {
    'Original Model':    'XGB_cnn_Original',
    'Grid Search':       'XGB_cnn_grid',
    'Randomized Search': 'XGB_cnn_random',
    'Optuna':            'XGB_cnn_optuna'
}

split_idx    = int(0.8 * len(df_backup))
train_actual = actual.iloc[:split_idx]
test_actual  = actual.iloc[split_idx:]

# NOTE: the initial training block has no OOF residual (Sections 7 & 9), so
# every 'XGB_cnn_*' column is NaN there. Those rows are dropped per-method
# before computing metrics -- otherwise mean_squared_error etc. would raise
# or silently propagate NaN into the comparison table. Test rows are
# unaffected (they were always out-of-sample).
results = []
for method_name, col_name in methods_map.items():
    pred       = df_backup[col_name]
    train_pred = pred.iloc[:split_idx].dropna()
    train_act  = train_actual.loc[train_pred.index]
    test_pred  = pred.iloc[split_idx:]
    test_act   = test_actual

    results.append({
        'Method':         method_name,
        'Train rows':     len(train_pred),
        'Train MSE':      mean_squared_error(train_act, train_pred),
        'Test MSE':       mean_squared_error(test_act,  test_pred),
        'Train MAE':      mean_absolute_error(train_act, train_pred),
        'Test MAE':       mean_absolute_error(test_act,  test_pred),
        'Train RMSE':     np.sqrt(mean_squared_error(train_act, train_pred)),
        'Test RMSE':      np.sqrt(mean_squared_error(test_act,  test_pred)),
        'Train MAPE (%)': np.mean(np.abs((train_act - train_pred) / train_act)) * 100,
        'Test MAPE (%)':  np.mean(np.abs((test_act  - test_pred)  / test_act))  * 100,
        'Train R²':       r2_score(train_act, train_pred),
        'Test R²':        r2_score(test_act,  test_pred)
    })

results_df = pd.DataFrame(results)
print("\n=== XGBoost-CNN Hybrid Model Performance Comparison ===")
print(results_df.to_string(index=False))

# Save the full comparison to CSV
results_df.to_csv('xgb_cnn_all_models_performance.csv', index=False)
print("\nSaved to 'xgb_cnn_all_models_performance.csv'")

# ── Plotly summary table ──────────────────────────────────────────────────────
numeric_cols = [c for c in results_df.columns if c != 'Method']
display_df   = results_df.copy()
for col in numeric_cols:
    display_df[col] = display_df[col].apply(lambda x: f"{x:.6f}")

fig_summary = go.Figure(go.Table(
    header=dict(
        values=[f'<b>{c}</b>' for c in results_df.columns],
        fill_color='steelblue',
        font=dict(color='white', size=11),
        align='center'
    ),
    cells=dict(
        values=[display_df[c] for c in display_df.columns],
        fill_color=[['lightcyan' if i % 2 == 0 else 'white'
                     for i in range(len(display_df))]],
        align='center'
    )
))
fig_summary.update_layout(
    title="XGBoost-CNN Hybrid Models — Full Performance Comparison",
    template="plotly_white",
    height=300
)
fig_summary.show()
# Out:
# === XGBoost-CNN Hybrid Model Performance Comparison ===
#            Method  Train rows  Train MSE  Test MSE  Train MAE  Test MAE  Train RMSE  Test RMSE  Train MAPE (%)  Test MAPE (%)  Train R²  Test R²
#    Original Model        2673   0.507289  0.519757   0.544836  0.544247    0.712242   0.720942       15.279134      14.774082  0.798720 0.784462
#       Grid Search        2673   0.510233  0.521854   0.548035  0.545473    0.714306   0.722394       15.237911      14.679074  0.797552 0.783593
# Randomized Search        2673   0.517496  0.532581   0.553037  0.550496    0.719372   0.729782       15.123211      14.532908  0.794670 0.779144
#            Optuna        2673   0.510570  0.517238   0.547254  0.543208    0.714542   0.719193       15.287798      14.693826  0.797418 0.785507
#
# Saved to 'xgb_cnn_all_models_performance.csv'
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2d9879fd-24a1-4fe2-9c8a-fc316d69fb01" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d9879fd-24a1-4fe2-9c8a-fc316d69fb01")) {                    Plotly.newPlot(                        "2d9879fd-24a1-4fe2-9c8a-fc316d69fb01",                        [{"cells":{"align":"center","fill":{"color":[["lightcyan","white","lightcyan","white"]]},"values":[["Original Model","Grid Search","Randomized Search","Optuna"],["2673.000000","2673.000000","2673.000000","2673.000000"],["0.507289","0.510233","0.517496","0.510570"],["0.519757","0.521854","0.532581","0.517238"],["0.544836","0.548035","0.553037","0.547254"],["0.544247","0.545473","0.550496","0.543208"],["0.712242","0.714306","0.719372","0.714542"],["0.720942","0.722394","0.729782","0.719193"],["15.279134","15.237911","15.123211","15.287798"],["14.774082","14.679074","14.532908","14.693826"],["0.798720","0.797552","0.794670","0.797418"],["0.784462","0.783593","0.779144","0.785507"]]},"header":{"align":"center","fill":{"color":"steelblue"},"font":{"color":"white","size":11},"values":["\u003cb\u003eMethod\u003c\u002fb\u003e","\u003cb\u003eTrain rows\u003c\u002fb\u003e","\u003cb\u003eTrain MSE\u003c\u002fb\u003e","\u003cb\u003eTest MSE\u003c\u002fb\u003e","\u003cb\u003eTrain MAE\u003c\u002fb\u003e","\u003cb\u003eTest MAE\u003c\u002fb\u003e","\u003cb\u003eTrain RMSE\u003c\u002fb\u003e","\u003cb\u003eTest RMSE\u003c\u002fb\u003e","\u003cb\u003eTrain MAPE (%)\u003c\u002fb\u003e","\u003cb\u003eTest MAPE (%)\u003c\u002fb\u003e","\u003cb\u003eTrain R²\u003c\u002fb\u003e","\u003cb\u003eTest R²\u003c\u002fb\u003e"]},"type":"table"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333 ...
